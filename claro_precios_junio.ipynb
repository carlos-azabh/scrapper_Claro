# %%
# Generated by Selenium IDE
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

import numpy as np
import pandas as pd 

options = webdriver.ChromeOptions()
# Inicia con la ventana maximizada
options.add_argument("--start-maximized")
driver = webdriver.Chrome(r"C:\Users\ASUS\anaconda3\Lib\site-packages\chromedriver_binary\chromedriver.exe", chrome_options=options)

# Abre el URL
driver.get("https://tiendaclaro.pe/equipo/58882/motorola/moto-g20-64gb")

WebDriverWait(driver,5).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'body > div.pushcrew-chrome-style-notification.pushcrew-chrome-style-notification-safari > div > div:nth-child(3) > div.pushcrew-button-wrapper > button.pushcrew-chrome-style-notification-btn.pushcrew-btn-close'))).click()

# Aleatoriedad. Darle 450 CON /290 SIN
driver.execute_script("window.scrollTo(0,450)")

time.sleep(1)
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[3]').click()

print("Prepago")

driver.find_element(By.XPATH, '//*[@id="Equipo-linea-nueva"]').click()
time.sleep(1)
pr1=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[2]/span[2]/strong').text
print(pr1)

time.sleep(1)
driver.find_element(By.XPATH, '//*[@id="Equipo-portabilidad"]').click()
time.sleep(1)
pr2=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[2]/span[2]/strong').text
print(pr2)

time.sleep(1)
driver.find_element(By.XPATH, '//*[@id="Equipo-renovacion"]').click()
time.sleep(1)
pr3=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[2]/span[2]/strong').text
print(pr3)

print("Pospago")
time.sleep(1)
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[1]').click()
driver.find_element(By.XPATH, '//*[@id="Equipo-linea-nueva"]').click()

print("Linea Nueva")

for i in np.arange(0,5,1):
    try:
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="precios'+str(i)+'"]').click()
        time.sleep(1)
        ln=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[1]/span[2]/strong').text
        print(ln)
    except:
        pass

driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()

for i in np.arange(5,9,1):
    try:
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="precios'+str(i)+'"]').click()
        time.sleep(1)
        ln=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[1]/span[2]/strong').text
        print(ln)
    except:
        pass
    
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()

for i in np.arange(9,12,1):
    try:
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="precios'+str(i)+'"]').click()
        time.sleep(1)
        ln=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[1]/span[2]/strong').text
        print(ln)
    except:
        pass

time.sleep(1)
driver.find_element(By.XPATH, '//*[@id="Equipo-portabilidad"]').click()
print("Portabilidad")

for i in np.arange(0,5,1):
    try:
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="precios'+str(i)+'"]').click()
        time.sleep(1)
        port=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[2]/span[2]/strong').text
        print(port)
    except:
        pass

driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()

for i in np.arange(5,9,1):
    try:
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="precios'+str(i)+'"]').click()
        time.sleep(1)
        port=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[2]/span[2]/strong').text
        print(port)
    except:
        pass
    
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()
driver.find_element(By.XPATH, '//*[@id="attributeproduct"]/div/div/div[2]/div[3]/div[2]/div[2]/div/div[3]/i').click()

for i in np.arange(9,12,1):
    try:
        time.sleep(1)
        driver.find_element(By.XPATH, '//*[@id="precios'+str(i)+'"]').click()
        time.sleep(1)
        port=driver.find_element(By.XPATH, '//*[@id="content-wrap"]/main/app-detail/main/div[2]/div[3]/div/section/div[2]/div[2]/span[2]/strong').text
        print(port)
    except:
        pass
# Out:
# <ipython-input-51-d7ad53a0dfbf>:19: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(r"C:\Users\ASUS\anaconda3\Lib\site-packages\chromedriver_binary\chromedriver.exe", chrome_options=options)
# Prepago
# S/ 839.00
# S/ 749.00
# S/ 749.00
# Pospago
# Linea Nueva
# S/ 839.00
# S/ 839.00
# S/ 829.00
# S/ 829.00
# S/ 819.00
# S/ 809.00
# S/ 809.00
# S/ 789.00
# S/ 789.00
# S/ 779.00
# S/ 759.00
# S/ 759.00
# Portabilidad
# S/ 709.00
# S/ 709.00
# S/ 709.00
# S/ 709.00
# S/ 699.00
# S/ 689.00
# S/ 639.00
# S/ 639.00
# S/ 629.00
# S/ 599.00
# S/ 549.00
# S/ 509.00
